# %% [markdown]
# <a href="https://colab.research.google.com/github/Motihari09052005/DileeppersonalResume.github.io/blob/main/Naive_Bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("/content/play_tennis.csv")
data.head()
# Out:
#   day   outlook  temp humidity    wind play
# 0  D1     Sunny   Hot     High    Weak   No
# 1  D2     Sunny   Hot     High  Strong   No
# 2  D3  Overcast   Hot     High    Weak  Yes
# 3  D4      Rain  Mild     High    Weak  Yes
# 4  D5      Rain  Cool   Normal    Weak  Yes

# %%
data.drop(columns=['day'],inplace=True)
data.head()
# Out:
#     outlook  temp humidity    wind play
# 0     Sunny   Hot     High    Weak   No
# 1     Sunny   Hot     High  Strong   No
# 2  Overcast   Hot     High    Weak  Yes
# 3      Rain  Mild     High    Weak  Yes
# 4      Rain  Cool   Normal    Weak  Yes

# %%
data['play'].value_counts()
# Out:
# play
# Yes    9
# No     5
# Name: count, dtype: int64

# %%
py=9/14
pn=5/14
print(py)
print(pn)
# Out:
# 0.6428571428571429
# 0.35714285714285715

# %%
# outlook column
pd.crosstab(data['outlook'],data['play'])
# Out:
# play      No  Yes
# outlook
# Overcast   0    4
# Rain       2    3
# Sunny      3    2

# %%
Pon = 0
Prn = 2/5
Psn=3/5
Poy=4/9
Pry=3/9
Psy=2/9
print(Pon)
print(Prn)
print(Psn)
print(Poy)
print(Pry)
print(Psy)
# Out:
# 0
# 0.4
# 0.6
# 0.4444444444444444
# 0.3333333333333333
# 0.2222222222222222

# %%
#temp
pd.crosstab(data['temp'],data['play'])
# Out:
# play  No  Yes
# temp
# Cool   1    3
# Hot    2    2
# Mild   2    4

# %%
pcoolNo=1/5
photNo=2/5
pmildNo=2/5
pcoolyes=3/9
photyes=2/9
pmildyes=4/9
print(pcoolNo)
print(photNo)
print(pmildNo)
print(pcoolyes)
print(photyes)
print(pmildyes)
# Out:
# 0.2
# 0.4
# 0.4
# 0.3333333333333333
# 0.2222222222222222
# 0.4444444444444444

# %%
# Humidity
pd.crosstab(data['humidity'],data['play'])
# Out:
# play      No  Yes
# humidity
# High       4    3
# Normal     1    6

# %%
pHighNo=4/5
pNormalNo=1/5
pHighyes=3/9
pNormalyes=6/9
print(pHighNo)
print(pNormalNo)
print(pHighyes)
print(pNormalyes)
# Out:
# 0.8
# 0.2
# 0.3333333333333333
# 0.6666666666666666

# %%
pd.crosstab(data['outlook'], data['play'])
# Out:
# play      No  Yes
# outlook
# Overcast   0    4
# Rain       2    3
# Sunny      3    2

# %%
pd.crosstab(data['wind'], data['play'])
# Out:
# play    No  Yes
# wind
# Strong   3    3
# Weak     2    6

# %%
pStrongNo=3/5
pWeakNo=2/5
pStrongyes=3/9
pWeakyes=6/9
print(pStrongNo)
print(pWeakNo)
print(pStrongyes)
print(pWeakyes)
# Out:
# 0.6
# 0.4
# 0.3333333333333333
# 0.6666666666666666

# %%
pyes=py*pcoolyes*photyes*pNormalyes*pWeakyes
print(pyes)
# Out:
# 0.021164021164021163

# %%
pyes=py*Psy*photyes*pHighyes*pWeakyes
print(pyes)
# Out:
# 0.007054673721340388

# %%
pno=pn*Psn*photNo*pHighNo*pWeakNo
print(pno)
# Out:
# 0.02742857142857143

# %%
# No play  play nahi hogi
